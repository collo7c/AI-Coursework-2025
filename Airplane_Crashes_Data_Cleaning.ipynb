# %% [markdown]
# <a href="https://colab.research.google.com/github/collo7c/AI-Coursework-2025/blob/main/Airplane_Crashes_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt



from google.colab import files
uploaded = files.upload()


df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')
# Out:
#      <input type="file" id="files-c5040405-6008-4ed9-b2fa-8161ef9d18e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5040405-6008-4ed9-b2fa-8161ef9d18e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
rows, cols = df.shape
print(f"The dataset has {rows} rows and {cols} columns.")
# Out:
# The dataset has 5268 rows and 13 columns.

# %%
df.tail(75)
# Out:
#             Date   Time                                           Location  \
# 5193  03/15/2008  08:15                                     Nbagu, Nigeria
# 5194  04/03/2008  11:00                                     Lawa, Suriname
# 5195  04/09/2008  23:27                                Bundeena, Australia
# 5196  04/11/2008  22:15                                 Chrisinau, Moldova
# 5197  04/15/2008  14:30                                        Goma, Congo
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# ...

# %%
# Display missing data per column
df.isnull().sum()

# Suggest appropriate treatment for missing values (not applied yet)
missing_treatment = {
    'Date': "Drop rows with missing dates (critical for time analysis)",
    'Location': "Fill with 'Unknown' or impute based on similar records",
    'Operator': "Fill with 'Unknown' or mode (most common operator)",
    'Aboard': "Impute with median (numerical data)",
    'Fatalities': "Impute with 0 or median depending on context",
    'Ground': "Fill missing with 0 (no fatalities on ground)",
    'Summary': "Fill with 'No summary available'"
}

missing_treatment
# Out:
# {'Date': 'Drop rows with missing dates (critical for time analysis)',
#  'Location': "Fill with 'Unknown' or impute based on similar records",
#  'Operator': "Fill with 'Unknown' or mode (most common operator)",
#  'Aboard': 'Impute with median (numerical data)',
#  'Fatalities': 'Impute with 0 or median depending on context',
#  'Ground': 'Fill missing with 0 (no fatalities on ground)',
#  'Summary': "Fill with 'No summary available'"}

# %%
fatality_locations = df[['Date', 'Location', 'Aboard', 'Fatalities']].copy()
fatality_locations.head()
# Out:
#          Date                            Location  Aboard  Fatalities
# 0  09/17/1908                 Fort Myer, Virginia     2.0         1.0
# 1  07/12/1912             AtlantiCity, New Jersey     5.0         5.0
# 2  08/06/1913  Victoria, British Columbia, Canada     1.0         1.0
# 3  09/09/1913                  Over the North Sea    20.0        14.0
# 4  10/17/1913          Near Johannisthal, Germany    30.0        30.0

# %%
max_fatalities = fatality_locations['Fatalities'].max()
deadliest_date = fatality_locations.loc[fatality_locations['Fatalities'] == max_fatalities, 'Date'].values[0]

print(f"The highest number of fatalities occurred on {deadliest_date} with {max_fatalities} fatalities.")
# Out:
# The highest number of fatalities occurred on 03/27/1977 with 583.0 fatalities.

# %%
# Compare aboard vs fatalities
fatality_locations['Survivors'] = fatality_locations['Aboard'] - fatality_locations['Fatalities']


no_fatalities = fatality_locations[fatality_locations['Fatalities'] == 0]
print(f"There are {len(no_fatalities)} crashes with no fatalities.")
no_fatalities.head()
# Out:
# There are 58 crashes with no fatalities.
#             Date                Location  Aboard  Fatalities  Survivors
# 108   10/21/1926         English Channel    12.0         0.0       12.0
# 387   03/05/1936      Near Tengya, China     6.0         0.0        6.0
# 889   10/08/1947     Near El Paso, Texas    54.0         0.0       54.0
# 897   11/11/1947      Gallup, New Mexico    25.0         0.0       25.0
# 1265  05/25/1953  Amsterdam, Netherlands    34.0         0.0       34.0

# %%
# Split Location column
split_location = fatality_locations['Location'].str.split(',', n=1, expand=True)
fatality_locations['Region'] = split_location[0]
fatality_locations['State/Country'] = split_location[1].str.strip()

fatality_locations.head()
# Out:
#          Date                            Location  Aboard  Fatalities  \
# 0  09/17/1908                 Fort Myer, Virginia     2.0         1.0
# 1  07/12/1912             AtlantiCity, New Jersey     5.0         5.0
# 2  08/06/1913  Victoria, British Columbia, Canada     1.0         1.0
# 3  09/09/1913                  Over the North Sea    20.0        14.0
# 4  10/17/1913          Near Johannisthal, Germany    30.0        30.0
#
#    Survivors              Region             State/Country
# 0        1.0           Fort Myer                  Virginia
# 1        0.0         AtlantiCity                New Jersey
# 2        0.0            Victoria  British Columbia, Canada
# 3        6.0  Over the North Sea                      None
# 4        0.0   Near Johannisthal                   Germany

# %%
top_100 = fatality_locations.sort_values(by='Fatalities', ascending=False).head(100)
top_100.head()
# Out:
#             Date                                 Location  Aboard  Fatalities  \
# 2963  03/27/1977                 Tenerife, Canary Islands   644.0       583.0
# 3568  08/12/1985    Mt. Osutaka, near Ueno Village, Japan   524.0       520.0
# 4455  11/12/1996                 Near Charkhidadri, India   349.0       349.0
# 2726  03/03/1974                Near Ermenonville, France   346.0       346.0
# 3562  06/23/1985  AtlantiOcean, 110 miles West of Ireland   329.0       329.0
#
#       Survivors             Region              State/Country
# 2963       61.0           Tenerife             Canary Islands
# 3568        4.0        Mt. Osutaka   near Ueno Village, Japan
# 4455        0.0  Near Charkhidadri                      India
# 2726        0.0  Near Ermenonville                     France
# 3562        0.0       AtlantiOcean  110 miles West of Ireland

# %%
# Get top 25 locations by total fatalities
top_25 = (fatality_locations.groupby('State/Country')['Fatalities']
           .sum()
           .sort_values(ascending=False)
           .head(25))

# Create pie chart
plt.figure(figsize=(10,10))
top_25.plot.pie(autopct='%1.1f%%', startangle=90, cmap='tab20')
plt.title('Top 25 Fatalities by Country/State')
plt.ylabel('')
plt.show()
